# %% [markdown]
# # What you should expect from image information dataframe

# %%
from sd_webui_gallery.images import calc_df_image_infos

df_infos = calc_df_image_infos()
df_infos.loc[:, ~df_infos.columns.isin(["path_full"])].tail().T
# Out:
#                                                                    4761  \
# date                                                         2023-10-05
# sub_folder                                               txt2img-images
# model                                                      anyhentai_20
# steps                                                                40
# sampler                                                 DPM++ 2M Karras
# full_generation_info  {'Steps': '40', 'Sampler': 'DPM++ 2M Karras', ...
# prompt                [masterpiece, best quality, high quality, perf...
# negative_prompt       [EasyNegativeV2 FastNegativeV2, ground, floor,...
# prompt_raw            masterpiece, best quality, high quality, perfe...
# negative_prompt_raw   EasyNegativeV2 FastNegativeV2, ground, floor, ...
#
#                                                                    4762  \
# date                                                         2023-10-05
# ...

# %%
df_infos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4766 entries, 0 to 4765
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   path_full             4766 non-null   object
#  1   date                  4766 non-null   object
#  2   sub_folder            4766 non-null   object
#  3   model                 4766 non-null   object
#  4   steps                 4766 non-null   object
#  5   sampler               4766 non-null   object
#  6   full_generation_info  4766 non-null   object
#  7   prompt                4766 non-null   object
#  8   negative_prompt       4766 non-null   object
#  9   prompt_raw            4766 non-null   object
#  10  negative_prompt_raw   4766 non-null   object
# dtypes: object(11)
# memory usage: 409.7+ KB
